# %%
from astropy.table import Table

from linetools.lists import parse

# %%
morton03 = Table.read('morton03_table2.fits.gz')

# %%
morton03
# Out:
# <Table length=3295>
#      A         el    nj    nk  group ...    Jk     Z     gk    gj     gamma
#    1 / s                             ...                              1 / s
#   float64    int64 int64 int64 int64 ... float64 int64 int64 int64   float64
# ------------ ----- ----- ----- ----- ... ------- ----- ----- ----- ------------
#  626500000.0     0     0     0     1 ...     0.0     1     6     2          0.0
#  167300000.0     0     0     0     1 ...     0.0     1     6     2  626500000.0
#   68190000.0     0     0     0     1 ...     0.0     1     6     2  189700000.0
#   34370000.0     0     0     0     1 ...     0.0     1     6     2   81270000.0
#   19730000.0     0     0     0     1 ...     0.0     1     6     2   42040000.0
#   12360000.0     0     0     0     1 ...     0.0     1     6     2   24500000.0
#    8255000.0     0     0     0     1 ...     0.0     1     6     2          0.0
#    5785000.0     0     0     0     1 ...     0.0     1     6     2          0.0
# ...

# %% [markdown]
# # Build the full table

# %%
parse._write_ref_table()
# Out:
# linetools.lists.parse: Reading linelist ---
#    /data/Projects/Python/linetools/linetools/data/lines/morton03_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /data/Projects/Python/linetools/linetools/data/lines/morton00_table2.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /data/Projects/Python/linetools/linetools/data/lines/verner96_tab1.fits.gz
# linetools.lists.parse: Reading linelist ---
#    /data/Projects/Python/linetools/linetools/data/lines/verner94_tab6.fits
# linetools.lists.parse: Reading linelist ---
#    /data/Projects/Python/linetools/linetools/data/lines/EUV_lines.ascii
# linetools.lists.parse: Reading linelist ---
#    /data/Projects/Python/linetools/linetools/data/lines/H2_resonance.ascii
# linetools.lists.parse: Reading linelist ---
#    /data/Projects/Python/linetools/linetools/data/lines/CO_UV.ascii
# linetools.lists.parse: Reading linelist ---
#    /data/Projects/Python/linetools/linetools/data/lines/galaxy_forbidden.ascii
# ...
